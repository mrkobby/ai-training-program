# %%
import pandas as pd

# %%
df = pd.read_csv('movies_metadata.csv',encoding='latin-1')

# %%
#-- DETAILS OF COLUMNS -- TITLE AND GENRES

df[['title','genres']]
# Out:
#                                                 title  \
# 0                                           Toy Story
# 1                                             Jumanji
# 2                                    Grumpier Old Men
# 3                                   Waiting to Exhale
# 4                         Father of the Bride Part II
# 5                                                Heat
# 6                                             Sabrina
# 7                                        Tom and Huck
# 8                                        Sudden Death
# 9                                           GoldenEye
# 10                             The American President
# 11                        Dracula: Dead and Loving It
# 12                                              Balto
# 13                                              Nixon
# 14                                   Cutthroat Island
# 15                                             Casino
# ...

# %%
#-- DETAILS OF THE MOVIE WITH TITLE 'GRUPIER OLD MEN'

df[df['title'] =='Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ... release_date  \
# 2  A family wedding reignites the ancient feud be...  ...   12/22/1995
#
#   revenue runtime                          spoken_languages    status  \
# 2       0     101  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count
# 2          6.5       92.0
#
# [1 rows x 24 columns]
