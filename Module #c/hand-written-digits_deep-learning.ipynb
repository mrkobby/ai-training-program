# %%
#--- ARTIFICIAL NEURAL NETWORK

import tensorflow
from tensorflow import keras
import pyforest

# %%
data = keras.datasets.mnist

# %%
(features_train, labels_train), (features_test, labels_test) = data.load_data()

# %%
features_train.shape
# Out:
# (60000, 28, 28)

# %%
features_test.shape
# Out:
# (10000, 28, 28)

# %%
plt.figure(figsize=(20,20))

for i in range(225):
    plt.subplot(15,15,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(features_train[i])
    plt.xlabel(labels_train[i])
plt.show()

# %%
plt.imshow(features_train[140])
plt.xticks([])
plt.yticks([])
plt.xlabel(labels_train[140])
# Out:
# Text(0.5, 0, '7')

# %%
#NORMALIZE

features_train = features_train / 255.0
features_test = features_test /255.0

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(features_train, labels_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0029 - accuracy: 0.9993
# Epoch 2/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 9.7733e-04 - accuracy: 0.9997
# Epoch 3/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0019 - accuracy: 0.9995
# Epoch 4/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0020 - accuracy: 0.9994
# Epoch 5/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 1.1340e-04 - accuracy: 0.9999s - loss: 4.3091e-05 - accuracy:
# Epoch 6/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0032 - accuracy: 0.9990
# Epoch 7/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0017 - accuracy: 0.9995
# Epoch 8/10
# 60000/60000 [==============================] - 6s 97us/sample - loss: 5.6802e-04 - accuracy: 0.9998
# Epoch 9/10
# ...

# %%
#test_loss, test_accuracy = model.evaluate(features_train, labels_train)

# %%
model.save('hand-written-model.h5')

# %%
#model.evaluate(features_test, labels_test)

# %%
plt.imshow(features_test[7])

# %%
np.argmax(model.predict(features_test)[7])
# Out:
# 9
